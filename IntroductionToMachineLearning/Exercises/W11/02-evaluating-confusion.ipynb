# %% [markdown]
# # Evaluating Confusion matrix
#
# **Overview**
# This exercise is about evaluation models based on the confusion matrix and the context.
#
#
# <article class="message">
#     <div class="message-body">
#         <strong>List of individual tasks</strong>
#         <ul style="list-style: none;">
#             <li>
#             <a href="#First2">Task 1: Evaluating relevance of models</a>
#             </li>
#         </ul>
#     </div>
# </article>
#
# This exercise provides different confusion matrices from classification tasks. This taks is about evaluating the relevance of the different models give the different viewpoints from fixional companies.
#
# ---
# **Task 1 (easy): Evaluating relevance of models👩‍💻💡📽️**
# 1. Run the centire notebook.
# 2. For each model, consider three related companies and explain whether each company would or would not choose to purchase the model based on its performance.
#
#
# ---## Model 1 (Diagnosis Model)
# <table>
# <tr>
# <td>
# **MedScan Technologies**
# A medical technology company that builds early-detection diagnostic tools for hospitals.
# </td>
# <td>
# **HealthInsure**
# A health-insurance provider that uses automated medical screenings to estimate patient risk before approving policies.
# </td>
# <td>
# **RapidCare Clinics**
# A chain of walk-in clinics that relies on fast, automated triage systems to decide which patients require urgent attention.
# </td>
# </tr>
# </table>

# %%
import confusion_util

confusion_util.make_model1()
# Out:
# === Diagnosis Model Metrics ===
# Accuracy:     0.865
# Precision:    0.860
# Recall:       0.875
# F1-Score:     0.867
# Specificity:  0.855
# MCC:          0.730
# ----------------------------------------

# %% [markdown]
# I think all companies would find this model usefull, as it is rather good
# at determining sick and healthy people correctly. In some of these cases
# we may be interested in having a little more TPs at the cost of less FN,
# as misclassifying a sick person as healthy may be costly!

# %% [markdown]
# ## Model 2 (Fraud Detection)
# <table>
# <tr>
# <td>
# **SecurePay Bank**
# A digital bank specializing in real-time fraud prevention for online transactions.
# </td>
# <td>
# **SmoothCheckout**
# An e-commerce platform focused on minimizing customer friction during payment and avoiding unnecessary fraud blocks.
# </td>
# <td>
# **RegComply Auditors**
# A financial auditing service that analyzes large transaction logs for regulatory and compliance reporting.
# </td>
# </tr>
# </table>

# %%
confusion_util.make_model2()
# Out:
# === Fraud Detection Model Metrics ===
# Accuracy:     0.988
# Precision:    1.000
# Recall:       0.229
# F1-Score:     0.373
# Specificity:  1.000
# MCC:          0.476
# ----------------------------------------

# %% [markdown]
# The bank would not be interested in this solution, as it misclassifies the vast majority of the fraud cases! this is severely bad in the banking industry.
#
# Depending on the ethics and regulation of smoothcheckout, they might like this option, but it may also bite them in the ass - at least no false frauds are highlighted...
#
# last case may not find much insight from this, as it is not that good at separating the classes, aha...

# %% [markdown]
# ## Model 3 (Spam Detection)
# <table>
# <tr>
# <td>
# **MailPro Premium**
# A premium email service that prioritizes user satisfaction and clean inboxes.
# </td>
# <td>
# **PhishShield Enterprise**
# A cybersecurity company offering phishing and malware email filtering for businesses.
# </td>
# <td>
# **PromoBlast**
# A marketing firm that sends large newsletter campaigns and needs reliable email deliverability.
# </td>
# </tr>
# </table>

# %%
confusion_util.make_model3()
# Out:
# === Spam Detection Model Metrics ===
# Accuracy:     0.950
# Precision:    0.990
# Recall:       0.780
# F1-Score:     0.873
# Specificity:  0.998
# MCC:          0.852
# ----------------------------------------

# %% [markdown]
# company one may thoroughly enjoy this model - receives most of the legit emails and rarely ever misses a spam email!!
#
# company two may like this to some extent, but there may be higher risk in missing legit emails, so depending on the operational stability and the manner of the legit emails, it might be useful or not.
#
# they sound like they want to spam me, so they probably do not like this product.

# %% [markdown]
# ## Model 4 (Churn Prediction Model)
# <table>
# <tr>
# <td>
# **TeleComPlus**
# A telecom provider that wants to identify and retain customers who are likely to cancel their subscription.
# </td>
# <td>
# **OfferSmart**
# A marketing company that delivers targeted promotional discounts to customers predicted to be at risk of leaving.
# </td>
# <td>
# **RevForecast**
# A business analytics firm that builds models to forecast future revenue based on customer churn patterns.
# </td>
# </tr>
# </table>

# %%
confusion_util.make_model4()
# Out:
# === Churn Prediction Model Metrics ===
# Accuracy:     0.867
# Precision:    0.881
# Recall:       0.839
# F1-Score:     0.860
# Specificity:  0.893
# MCC:          0.734
# ----------------------------------------

# %% [markdown]
# the model is pretty good, so i do not see why they would not want it!
